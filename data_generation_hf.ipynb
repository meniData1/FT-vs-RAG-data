# %%
import os
import json
import pandas as pd
import random
from tqdm import tqdm
from vllm import LLM, SamplingParams
tqdm.pandas()
random.seed(42)

# %%
CHUNK_SIZE = 10
NUM_QUESTIONS_PER_CHUNK = 4

# %%
meta_prompt = """\
Context information is below.\n
Given the context information and no prior knowledge.\n
Generate only questions based on the below query.\n
The context of each question should be easily inferred by reading the question. If you are referring to a specific event, mention the exact name and date of the event.\n

You are a Teacher/ Professor. Your task is to setup \
{num_questions_per_chunk} multiple-choice questions for an upcoming \
quiz/examination. The questions should be diverse in nature \
across the document. Do not repeat the same question twice. Restrict the questions to the \
context information provided. Each question should have exactly four possible answers. Only one answer should be correct. \
Your reply must be a single number (0, 1, 2, or 3) related to the correct answer. \ 
Return a valid JSON formatted string with the following fields: \
question, possible_answers, correct_answer.\
"""

context_prompt = """---------------------\n{context_str}\n---------------------\n\
Each question should have an index value as its key, given by the following list: {question_indices}. The end result should look like this:\n\n
{{'Q_23': {{'question': 'In what year did the NBA playoffs for the 2022-23 season begin?', 'possible_answers': ['January 1, 2023', 'April 1, 2023', 'June 1, 2023', 'October 1, 2022'], 'correct_answer': 1}}, 'Q_16254': {{'question': 'Which team won the 2023 NBA Finals?', 'possible_answers': ['Boston Celtics', 'Golden State Warriors', 'Denver Nuggets', 'Miami Heat'], 'correct_answer': 2}}}}\n\
"""

num_questions_per_chunk = 4
question_indices = ["Q_23", "Q_16254", "Q_224", "Q_3"]
context_str = "The 2023 NBA playoffs was the postseason tournament of the National Basketball Association's 2022–23 season. \
The playoffs began on April 15 and concluded on June 12 with the Denver Nuggets winning the 2023 NBA Finals."

message= [{"role": "user", "content": meta_prompt.format(num_questions_per_chunk=num_questions_per_chunk) + context_prompt.format(context_str=context_str, question_indices=question_indices)}]

# %% [markdown]
# ## Load full data

# %%
df = pd.read_csv("wiki_events_aug-nov_2023.csv", index_col=0)
df.fillna("None", inplace=True)
df['text_len'] = df['text'].str.len()
df = df[df['text_len'] > 100]

df['prefix'] = ("### Article: " + df['topic_name'] + ".\n" +
                "### Section: " + df['section'] + ".\n" +
                "### Subsection: " + df['subsection'] + ".\n" +
                "### Text: ")
df = df[['prefix', 'text']]
df.reset_index(inplace=True, drop=True)
df
# Out:
#                                                 prefix  \
# 0    ### Article: 2023 Louisiana wildfires.\n### Se...
# 1    ### Article: 2023 Louisiana wildfires.\n### Se...
# 2    ### Article: 2023 Louisiana wildfires.\n### Se...
# 3    ### Article: 2023 Louisiana wildfires.\n### Se...
# 4    ### Article: United States abortion protests (...
# ..                                                 ...
# 682  ### Article: 2023 Virginia Senate election.\n#...
# 683  ### Article: 2023 Virginia Senate election.\n#...
# 684  ### Article: 2023 Virginia Senate election.\n#...
# 685  ### Article: 2023 Virginia Senate election.\n#...
# 686  ### Article: 2023 Virginia Senate election.\n#...
#
#                                                   text
# 0    In a three-month period from August to October...
# 1    On August 22, a fire started in Beauregard Par...
# 2    On August 24, a fire described as "out of cont...
# 3    The Federal Emergency Management Agency approv...
# 4    A series of ongoing protests supporting aborti...
# ..                                                 ...
# 682  Five incumbent senators, four Democrats and on...
# 683  District 21: Won by State Delegate Angelia Wil...
# 684  District 1: Won by farmer Timmy French\r\nDist...
# 685  Incumbent Republican Jen Kiggans, first electe...
# 686  Democrat Jennifer McClellan, first elected in ...
#
# [687 rows x 2 columns]

# %%
df_dict = df.to_dict(orient='records')
corpus = []

for row in tqdm(df_dict):
    sentences = row['text'].split(".")
    sentences = [s.strip() + '.' for s in sentences if len(s) > 0]
    chunks = [sentences[i:i + CHUNK_SIZE] for i in range(0, len(sentences), CHUNK_SIZE)]
    chunks = [' '.join(chunk).strip() for chunk in chunks]
    
    # Limit the number of chunks for each article to 2
    if len(chunks) > 2:
        chunks = random.sample(chunks, 2)
    
    # Adding the prefix to each chunk
    chunks = [row['prefix'] + chunk for chunk in chunks]
    corpus.extend(chunks)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 687/687 [00:00<00:00, 152985.76it/s]

# %% [markdown]
# ## Generating the dataset

# %%
from transformers import AutoTokenizer
model_id = "casperhansen/llama-3-70b-instruct-awq"
model = LLM(model_id)
tokenizer = AutoTokenizer.from_pretrained(model_id)

terminators = [
    tokenizer.eos_token_id,
    tokenizer.convert_tokens_to_ids("<|eot_id|>")
]
# Out:
# WARNING 05-26 18:54:39 config.py:179] awq quantization is not fully optimized yet. The speed can be slower than non-quantized models.
# INFO 05-26 18:54:39 llm_engine.py:73] Initializing an LLM engine with config: model='casperhansen/llama-3-70b-instruct-awq', tokenizer='casperhansen/llama-3-70b-instruct-awq', tokenizer_mode=auto, revision=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.float16, max_seq_len=8192, download_dir=None, load_format=auto, tensor_parallel_size=1, quantization=awq, enforce_eager=False, seed=0)
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# INFO 05-26 18:55:09 llm_engine.py:223] # GPU blocks: 4729, # CPU blocks: 819
# INFO 05-26 18:55:10 model_runner.py:394] Capturing the model for CUDA graphs. This may lead to unexpected consequences if the model is not static. To run the model in eager mode, set 'enforce_eager=True' or use '--enforce-eager' in the CLI.
# INFO 05-26 18:55:27 model_runner.py:437] Graph capturing finished in 17 secs.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
def postprocess_output(output):
    output = output.outputs[0].text
    output = output[output.find("{"):output.rfind("}")+1]
    output = output.replace("\'", "\"").replace('\\', '')
    output = json.loads(output)
    return output

# %%
sampling_params = SamplingParams(
        temperature=0.2, top_p=0.95, max_tokens=500, stop_token_ids=terminators)
output = model.generate(tokenizer.apply_chat_template(message, tokenize=False),
                        sampling_params)
print(postprocess_output(output[0]))
# Out:
# Processed prompts: 100%|██████████████████████████████████████████████████████████████████| 1/1 [00:15<00:00, 15.07s/it]
# {'Q_23': {'question': 'In what year did the NBA playoffs for the 2022-23 season begin?', 'possible_answers': ['2021', '2022', '2023', '2024'], 'correct_answer': 2}, 'Q_16254': {'question': 'Which team won the 2023 NBA Finals?', 'possible_answers': ['Boston Celtics', 'Golden State Warriors', 'Denver Nuggets', 'Miami Heat'], 'correct_answer': 2}, 'Q_224': {'question': 'On which date did the 2023 NBA playoffs conclude?', 'possible_answers': ['June 1, 2023', 'June 12, 2023', 'June 20, 2023', 'June 30, 2023'], 'correct_answer': 1}, 'Q_3': {'question': 'On which date did the 2023 NBA playoffs begin?', 'possible_answers': ['April 10, 2023', 'April 15, 2023', 'April 20, 2023', 'April 25, 2023'], 'correct_answer': 1}}

# %%
count = 0
json_path = 'current_events_questions_llama3.json'

NUM_PROMPTS_AT_ONCE = 10
corpus_chunks = [corpus[i:i+NUM_PROMPTS_AT_ONCE] for i in range(0, len(corpus), NUM_PROMPTS_AT_ONCE)]

p_bar = tqdm(corpus_chunks, desc="Processing chunks")
for corpus_chunk in p_bar:
    messages = []
    for chunk in corpus_chunk:
        question_indices = [f"Q_{i}" for i in range(count*NUM_QUESTIONS_PER_CHUNK, (count+1)*NUM_QUESTIONS_PER_CHUNK)]
        message = [{
            "role": "user", 
            "content": meta_prompt.format(num_questions_per_chunk=NUM_QUESTIONS_PER_CHUNK) + context_prompt.format(context_str=chunk, question_indices=question_indices)
        }]
        messages.append(tokenizer.apply_chat_template(message, tokenize=False))
    
    sampling_params = SamplingParams(temperature=0.2, top_p=0.95, max_tokens=500, stop_token_ids=terminators)
    output = model.generate(messages, sampling_params)
    for i in range(len(output)):
        try:
            python_dict = postprocess_output(output[i])
        except Exception as e:
            continue
        
        chunk = corpus_chunk[i]
        for q in python_dict:
            python_dict[q]['context'] = chunk
    
        if count > 0:
            with open(json_path, 'r') as json_file:
                json_dict = json.load(json_file)
            json_dict.update(python_dict)
        else:
            json_dict = python_dict
    
        if len(json_dict) > 0:
            with open(json_path, 'w') as json_file:
                json.dump(json_dict, json_file)
        count += 1
        p_bar.set_postfix(successes=count)
# Out:
# Processing chunks:   0%|                                                                         | 0/94 [00:00<?, ?it/s]
#
# Processed prompts:   0%|                                                                         | 0/10 [00:00<?, ?it/s]
#
# Processed prompts:  10%|██████▌                                                          | 1/10 [00:28<04:15, 28.35s/it]
#
# Processed prompts:  20%|█████████████                                                    | 2/10 [00:29<01:36, 12.10s/it]
#
# Processed prompts:  30%|███████████████████▌                                             | 3/10 [00:29<00:46,  6.63s/it]
#
# Processed prompts:  40%|██████████████████████████                                       | 4/10 [00:29<00:25,  4.30s/it]
#
# Processed prompts:  50%|████████████████████████████████▌                                | 5/10 [00:30<00:15,  3.01s/it]
#
# Processed prompts:  60%|███████████████████████████████████████                          | 6/10 [00:31<00:08,  2.13s/it]
#
# Processed prompts:  70%|█████████████████████████████████████████████▌                   | 7/10 [00:31<00:04,  1.47s/it]
#
# Processed prompts:  80%|████████████████████████████████████████████████████             | 8/10 [00:32<00:03,  1.58s/it]
#
# Processed prompts:  90%|██████████████████████████████████████████████████████████▌      | 9/10 [00:33<00:01,  1.19s/it]
#
# Processed prompts: 100%|████████████████████████████████████████████████████████████████| 10/10 [00:34<00:00,  3.49s/it]
# Processing chunks:   1%|▌                                                   | 1/94 [00:34<54:03, 34.88s/it, successes=6]
#
# Processed prompts:   0%|                                                                         | 0/10 [00:00<?, ?it/s]
#
# Processed prompts:  10%|██████▌                                                          | 1/10 [00:28<04:16, 28.45s/it]
#
# Processed prompts:  20%|█████████████                                                    | 2/10 [00:29<01:38, 12.30s/it]
#
# Processed prompts:  30%|███████████████████▌                                             | 3/10 [00:29<00:47,  6.82s/it]
#
# Processed prompts:  40%|██████████████████████████                                       | 4/10 [00:29<00:25,  4.20s/it]
#
# Processed prompts:  50%|████████████████████████████████▌                                | 5/10 [00:30<00:14,  2.86s/it]
#
# Processed prompts:  70%|█████████████████████████████████████████████▌                   | 7/10 [00:30<00:04,  1.44s/it]
#
# Processed prompts:  80%|████████████████████████████████████████████████████             | 8/10 [00:31<00:02,  1.32s/it]
#
# Processed prompts: 100%|████████████████████████████████████████████████████████████████| 10/10 [00:32<00:00,  3.22s/it]
# Processing chunks:   2%|█                                                  | 2/94 [01:07<51:06, 33.33s/it, successes=12]
#
# Processed prompts:   0%|                                                                         | 0/10 [00:00<?, ?it/s]
#
# Processed prompts:  10%|██████▌                                                          | 1/10 [00:29<04:27, 29.67s/it]
#
# Processed prompts:  20%|█████████████                                                    | 2/10 [00:30<01:42, 12.77s/it]
#
# Processed prompts:  30%|███████████████████▌                                             | 3/10 [00:30<00:49,  7.10s/it]
#
# Processed prompts:  40%|██████████████████████████                                       | 4/10 [00:31<00:27,  4.52s/it]
#
# Processed prompts:  50%|████████████████████████████████▌                                | 5/10 [00:32<00:17,  3.41s/it]
#
# Processed prompts:  60%|███████████████████████████████████████                          | 6/10 [00:33<00:09,  2.43s/it]
#
# Processed prompts:  70%|█████████████████████████████████████████████▌                   | 7/10 [00:33<00:05,  1.73s/it]
#
# Processed prompts:  80%|████████████████████████████████████████████████████             | 8/10 [00:35<00:03,  1.57s/it]
#
# Processed prompts:  90%|██████████████████████████████████████████████████████████▌      | 9/10 [00:35<00:01,  1.23s/it]
#
# Processed prompts: 100%|████████████████████████████████████████████████████████████████| 10/10 [00:35<00:00,  3.57s/it]
# Processing chunks:   3%|█▋                                                 | 3/94 [01:42<52:11, 34.41s/it, successes=19]
#
# Processed prompts:   0%|                                                                         | 0/10 [00:00<?, ?it/s]
#
# Processed prompts:  10%|██████▌                                                          | 1/10 [00:32<04:50, 32.24s/it]
#
# Processed prompts:  20%|█████████████                                                    | 2/10 [00:33<01:50, 13.79s/it]
#
# Processed prompts:  30%|███████████████████▌                                             | 3/10 [00:33<00:52,  7.55s/it]
#
# Processed prompts:  40%|██████████████████████████                                       | 4/10 [00:33<00:28,  4.74s/it]
#
# Processed prompts:  50%|████████████████████████████████▌                                | 5/10 [00:33<00:15,  3.12s/it]
#
# Processed prompts:  60%|███████████████████████████████████████                          | 6/10 [00:34<00:09,  2.26s/it]
#
# Processed prompts:  80%|████████████████████████████████████████████████████             | 8/10 [00:34<00:02,  1.18s/it]
#
# Processed prompts:  90%|██████████████████████████████████████████████████████████▌      | 9/10 [00:34<00:00,  1.06it/s]
#
# Processed prompts: 100%|████████████████████████████████████████████████████████████████| 10/10 [00:35<00:00,  3.54s/it]
# Processing chunks:   4%|██▏                                                | 4/94 [02:18<52:12, 34.81s/it, successes=25]
#
# Processed prompts:   0%|                                                                         | 0/10 [00:00<?, ?it/s]
#
# Processed prompts:  10%|██████▌                                                          | 1/10 [00:28<04:18, 28.77s/it]
#
# Processed prompts:  20%|█████████████                                                    | 2/10 [00:29<01:38, 12.28s/it]
#
# Processed prompts:  30%|███████████████████▌                                             | 3/10 [00:30<00:48,  6.98s/it]
#
# Processed prompts:  40%|██████████████████████████                                       | 4/10 [00:30<00:27,  4.52s/it]
#
# Processed prompts:  60%|███████████████████████████████████████                          | 6/10 [00:31<00:08,  2.19s/it]
#
# Processed prompts:  70%|█████████████████████████████████████████████▌                   | 7/10 [00:31<00:04,  1.62s/it]
#
# Processed prompts:  90%|██████████████████████████████████████████████████████████▌      | 9/10 [00:32<00:01,  1.17s/it]
#
# Processed prompts: 100%|████████████████████████████████████████████████████████████████| 10/10 [00
/it]
#
# Processed prompts:  80%|████████████████████████████████████████████████████             | 8/10 [00:37<00:03,  1.87s/it]
#
# Processed prompts:  90%|██████████████████████████████████████████████████████████▌      | 9/10 [00:37<00:01,  1.50s/it]
#
# Processed prompts: 100%|████████████████████████████████████████████████████████████████| 10/10 [00:38<00:00,  3.85s/it]
# Processing chunks:  74%|████████████████████████████████████▍            | 70/94 [42:20<15:12, 38.04s/it, successes=398]
#
# Processed prompts:   0%|                                                                         | 0/10 [00:00<?, ?it/s]
#
# Processed prompts:  10%|██████▌                                                          | 1/10 [00:32<04:48, 32.09s/it]
#
# Processed prompts:  20%|█████████████                                                    | 2/10 [00:32<01:48, 13.57s/it]
#
# Processed prompts:  30%|███████████████████▌                                             | 3/10 [00:32<00:52,  7.43s/it]
#
# Processed prompts:  40%|██████████████████████████                                       | 4/10 [00:33<00:27,  4.57s/it]
#
# Processed prompts:  50%|████████████████████████████████▌                                | 5/10 [00:33<00:14,  2.97s/it]
#
# Processed prompts:  70%|█████████████████████████████████████████████▌                   | 7/10 [00:33<00:04,  1.55s/it]
#
# Processed prompts:  80%|████████████████████████████████████████████████████             | 8/10 [00:33<00:02,  1.17s/it]
#
# Processed prompts:  90%|██████████████████████████████████████████████████████████▌      | 9/10 [00:34<00:01,  1.21s/it]
#
# Processed prompts: 100%|████████████████████████████████████████████████████████████████| 10/10 [00:35<00:00,  3.51s/it]
# Processing chunks:  74%|████████████████████████████████████▍            | 70/94 [42:55<15:12, 38.04s/it, successes=399]
#
# Processed prompts:  60%|███████████████████████████████████████                          | 6/10 [00:34<00:10,  2.73s/it]
#
# Processed prompts:  70%|█████████████████████████████████████████████▌                   | 7/10 [00:34<00:06,  2.08s/it]
#
# Processed prompts:  80%|████████████████████████████████████████████████████             | 8/10 [00:34<00:03,  1.52s/it]
#
# Processed prompts:  90%|██████████████████████████████████████████████████████████▌      | 9/10 [00:35<00:01,  1.20s/it]
#
# Processed prompts: 100%|████████████████████████████████████████████████████████████████| 10/10 [00:36<00:00,  3.62s/it]
# Processing chunks:  96%|██████████████████████████████████████████████▉  | 90/94 [54:24<02:28, 37.13s/it, successes=505]
#
# Processed prompts:   0%|                                                                         | 0/10 [00:00<?, ?it/s]
#
# Processed prompts:  10%|██████▌                                                          | 1/10 [00:28<04:19, 28.87s/it]
#
# Processed prompts:  20%|█████████████                                                    | 2/10 [00:31<01:45, 13.18s/it]
#
# Processed prompts:  30%|███████████████████▌                                             | 3/10 [00:31<00:51,  7.36s/it]
#
# Processed prompts:  40%|██████████████████████████                                       | 4/10 [00:31<00:27,  4.53s/it]
#
# Processed prompts:  60%|███████████████████████████████████████                          | 6/10 [00:31<00:08,  2.16s/it]
#
# Processed prompts:  70%|█████████████████████████████████████████████▌                   | 7/10 [00:31<00:04,  1.60s/it]
#
# Processed prompts:  80%|████████████████████████████████████████████████████             | 8/10 [00:32<00:02,  1.30s/it]
#
# Processed prompts:  90%|██████████████████████████████████████████████████████████▌      | 9/10 [00:33<00:01,  1.18s/it]
#
# Processed prompts: 100%|████████████████████████████████████████████████████████████████| 10/10 [00:33<00:00,  3.36s/it]
# Processing chunks:  97%|███████████████████████████████████████████████▍ | 91/94 [54:57<01:48, 36.09s/it, successes=510]
#
# Processed prompts:   0%|                                                                         | 0/10 [00:00<?, ?it/s]
#
# Processed prompts:  10%|██████▌                                                          | 1/10 [00:29<04:29, 29.99s/it]
#
# Processed prompts:  20%|█████████████                                                    | 2/10 [00:30<01:39, 12.43s/it]
#
# Processed prompts:  30%|███████████████████▌                                             | 3/10 [00:30<00:48,  6.89s/it]
#
# Processed prompts:  40%|██████████████████████████                                       | 4/10 [00:30<00:25,  4.22s/it]
#
# Processed prompts:  50%|████████████████████████████████▌                                | 5/10 [00:30<00:13,  2.76s/it]
#
# Processed prompts:  60%|███████████████████████████████████████                          | 6/10 [00:30<00:07,  1.87s/it]
#
# Processed prompts:  70%|█████████████████████████████████████████████▌                   | 7/10 [00:31<00:04,  1.48s/it]
#
# Processed prompts:  80%|████████████████████████████████████████████████████             | 8/10 [00:32<00:02,  1.38s/it]
#
# Processed prompts:  90%|██████████████████████████████████████████████████████████▌      | 9/10 [00:33<00:01,  1.19s/it]
#
# Processed prompts: 100%|████████████████████████████████████████████████████████████████| 10/10 [00:33<00:00,  3.38s/it]
# Processing chunks:  98%|███████████████████████████████████████████████▉ | 92/94 [55:31<01:10, 35.42s/it, successes=516]
#
# Processed prompts:   0%|                                                                         | 0/10 [00:00<?, ?it/s]
#
# Processed prompts:  10%|██████▌                                                          | 1/10 [00:27<04:11, 27.90s/it]
#
# Processed prompts:  20%|█████████████                                                    | 2/10 [00:28<01:35, 11.88s/it]
#
# Processed prompts:  50%|████████████████████████████████▌                                | 5/10 [00:29<00:17,  3.50s/it]
#
# Processed prompts:  60%|███████████████████████████████████████                          | 6/10 [00:29<00:11,  2.82s/it]
#
# Processed prompts:  90%|██████████████████████████████████████████████████████████▌      | 9/10 [00:30<00:01,  1.38s/it]
#
# Processed prompts: 100%|████████████████████████████████████████████████████████████████| 10/10 [00:31<00:00,  3.11s/it]
# Processing chunks:  99%|████████████████████████████████████████████████▍| 93/94 [56:02<00:34, 34.14s/it, successes=522]
#
# Processed prompts:   0%|                                                                         | 0/10 [00:00<?, ?it/s]
#
# Processed prompts:  10%|██████▌                                                          | 1/10 [00:26<03:54, 26.06s/it]
#
# Processed prompts:  20%|█████████████                                                    | 2/10 [00:26<01:26, 10.81s/it]
#
# Processed prompts:  30%|███████████████████▌                                             | 3/10 [00:26<00:43,  6.21s/it]
#
# Processed prompts:  40%|██████████████████████████                                       | 4/10 [00:27<00:23,  3.92s/it]
#
# Processed prompts:  50%|████████████████████████████████▌                                | 5/10 [00:27<00:13,  2.70s/it]
#
# Processed prompts:  60%|███████████████████████████████████████                          | 6/10 [00:28<00:07,  1.82s/it]
#
# Processed prompts:  70%|█████████████████████████████████████████████▌                   | 7/10 [00:28<00:04,  1.50s/it]
#
# Processed prompts:  80%|████████████████████████████████████████████████████             | 8/10 [00:29<00:02,  1.29s/it]
#
# Processed prompts: 100%|████████████████████████████████████████████████████████████████| 10/10 [00:30<00:00,  3.03s/it]
# Processing chunks: 100%|█████████████████████████████████████████████████| 94/94 [56:33<00:00, 36.10s/it, successes=529]

# %% [markdown]
# ## Correcting the dataset
# Keeps only specific questions

# %%
questions_dataset = pd.read_json(json_path).T

# %%
questions_dataset
# Out:
#                                                  question  \
# Q_0     On what date did the Supreme Court officially ...
# Q_1     What was the margin of the Supreme Court decis...
# Q_2     What percentage of the American public was spl...
# Q_3     How did international observers and foreign le...
# Q_24    Where was a demonstration held in London durin...
# ...                                                   ...
# Q_2067  What is the number of the district that Jeff C...
# Q_2088  In which district did Timmy French win the ele...
# Q_2089                Who won the election in District 3?
# Q_2090   How many districts are mentioned in the article?
# Q_2091               Who won the election in District 27?
#
#                                          possible_answers correct_answer  \
# Q_0     [June 24, 2021, June 24, 2022, July 24, 2022, ...              1
# Q_1                                  [6–3, 5–4, 7–2, 8–1]              1
# Q_2          [40 to 45%, 50 to 55%, 55 to 60%, 60 to 65%]              2
# Q_3     [They generally supported the decision, They w...              2
# Q_24       [Birmingham, Battersea, Manchester, Liverpool]              1
# ...                                                   ...            ...
# Q_2067                                       [5, 6, 7, 8]              1
# Q_2088  [District 1, District 3, District 10, District...              0
# Q_2089  [Timmy French, Chris Head, John McGuire, Emily...              1
# Q_2090                                       [3, 4, 5, 6]              3
# Q_2091  [Emily Brewer, Tara Durant, John McGuire, Chri...              1
#
#                                                   context
# Q_0     ### Article: United States abortion protests (...
# Q_1     ### Article: United States abortion protests (...
# Q_2     ### Article: United States abortion protests (...
# Q_3     ### Article: United States abortion protests (...
# Q_24    ### Article: United States abortion protests (...
# ...                                                   ...
# Q_2067  ### Article: 2023 Virginia House of Delegates ...
# Q_2088  ### Article: 2023 Virginia Senate election.\n#...
# Q_2089  ### Article: 2023 Virginia Senate election.\n#...
# Q_2090  ### Article: 2023 Virginia Senate election.\n#...
# Q_2091  ### Article: 2023 Virginia Senate election.\n#...
#
# [376 rows x 4 columns]

# %%
questions_dataset['context_num'] = pd.factorize(questions_dataset['context'])[0]

# %%
questions_dataset.shape
# Out:
# (376, 5)

# %%
questions_dataset.context_num.nunique()
# Out:
# 87

# %%
def clean_correct_answers(x):
    try:
        return int(x) if int(x) in range(4) else None 
    except:
        return None
questions_dataset.correct_answer = questions_dataset.correct_answer.apply(lambda x: clean_correct_answers(x))
questions_dataset.dropna(inplace=True)

# %%
questions_dataset
# Out:
#                                                  question  \
# Q_0     On what date did the Supreme Court officially ...
# Q_1     What was the margin of the Supreme Court decis...
# Q_2     What percentage of the American public was spl...
# Q_3     How did international observers and foreign le...
# Q_24    Where was a demonstration held in London durin...
# ...                                                   ...
# Q_2067  What is the number of the district that Jeff C...
# Q_2088  In which district did Timmy French win the ele...
# Q_2089                Who won the election in District 3?
# Q_2090   How many districts are mentioned in the article?
# Q_2091               Who won the election in District 27?
#
#                                          possible_answers  correct_answer  \
# Q_0     [June 24, 2021, June 24, 2022, July 24, 2022, ...               1
# Q_1                                  [6–3, 5–4, 7–2, 8–1]               1
# Q_2          [40 to 45%, 50 to 55%, 55 to 60%, 60 to 65%]               2
# Q_3     [They generally supported the decision, They w...               2
# Q_24       [Birmingham, Battersea, Manchester, Liverpool]               1
# ...                                                   ...             ...
# Q_2067                                       [5, 6, 7, 8]               1
# Q_2088  [District 1, District 3, District 10, District...               0
# Q_2089  [Timmy French, Chris Head, John McGuire, Emily...               1
# Q_2090                                       [3, 4, 5, 6]               3
# Q_2091  [Emily Brewer, Tara Durant, John McGuire, Chri...               1
#
#                                                   context  context_num
# Q_0     ### Article: United States abortion protests (...            0
# Q_1     ### Article: United States abortion protests (...            0
# Q_2     ### Article: United States abortion protests (...            0
# Q_3     ### Article: United States abortion protests (...            0
# Q_24    ### Article: United States abortion protests (...            1
# ...                                                   ...          ...
# Q_2067  ### Article: 2023 Virginia House of Delegates ...           85
# Q_2088  ### Article: 2023 Virginia Senate election.\n#...           86
# Q_2089  ### Article: 2023 Virginia Senate election.\n#...           86
# Q_2090  ### Article: 2023 Virginia Senate election.\n#...           86
# Q_2091  ### Article: 2023 Virginia Senate election.\n#...           86
#
# [376 rows x 5 columns]

# %%
# dumb heuristic to remove contexts with no information
questions_dataset = questions_dataset[questions_dataset.context.apply(lambda x: len(x.split())>70)]
questions_dataset = questions_dataset.reset_index().rename(columns={'index': 'orig_question_num', 'context': 'text'})

# %%
questions_dataset
# Out:
#     orig_question_num                                           question  \
# 0                 Q_0  On what date did the Supreme Court officially ...
# 1                 Q_1  What was the margin of the Supreme Court decis...
# 2                 Q_2  What percentage of the American public was spl...
# 3                 Q_3  How did international observers and foreign le...
# 4                Q_76  What is the current number of counties require...
# ..                ...                                                ...
# 259            Q_1983  At what time was the strike officially suspend...
# 260            Q_2000  By what date had the FAA concluded the safety ...
# 261            Q_2001  What was the original target launch date annou...
# 262            Q_2002  What was the reason for the flight being delay...
# 263            Q_2003  On what date did the FWS conclude its environm...
#
#                                       possible_answers  correct_answer  \
# 0    [June 24, 2021, June 24, 2022, July 24, 2022, ...               1
# 1                                 [6–3, 5–4, 7–2, 8–1]               1
# 2         [40 to 45%, 50 to 55%, 55 to 60%, 60 to 65%]               2
# 3    [They generally supported the decision, They w...               2
# 4    [30 counties, 44 counties, 50 counties, 88 cou...               1
# ..                                                 ...             ...
# 259  [12:00am on November 8, 12:01am on November 9,...               1
# 260  [October 15, 2023, October 31, 2023, November ...               1
# 261  [November 10, 2023, November 15, 2023, Novembe...               2
# 262  [Weather conditions, Technical issues with the...               2
# 263  [November 10, 2023, November 12, 2023, Novembe...               2
#
#                                                   text  context_num
# 0    ### Article: United States abortion protests (...            0
# 1    ### Article: United States abortion protests (...            0
# 2    ### Article: United States abortion protests (...            0
# 3    ### Article: United States abortion protests (...            0
# 4    ### Article: August 2023 Ohio Issue 1.\n### Se...            3
# ..                                                 ...          ...
# 259  ### Article: 2023 SAG-AFTRA strike.\n### Secti...           24
# 260  ### Article: SpaceX Starship Second Integrated...           82
# 261  ### Article: SpaceX Starship Second Integrated...           82
# 262  ### Article: SpaceX Starship Second Integrated...           82
# 263  ### Article: SpaceX Starship Second Integrated...           82
#
# [264 rows x 6 columns]

# %%
questions_dataset.to_csv('current_events_questions_updated_hf_llama_3.csv', index=False)
